# %%
import os
import requests
import re
import csv
from bs4 import BeautifulSoup

def get_website():
    global url
    url = input("Enter a valid url: ")
    result = requests.get(url)
    source = result.content
    global soup
    soup = BeautifulSoup(source, "lxml")
    return soup

get_website()

print(soup.get_text())
# Out:
# Enter a valid url: https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PAI NORTHERN THAI KITCHEN - 4017 Photos & 2934 Reviews - Thai - 18 Duncan Street, Toronto, ON - Restaurant Reviews - Phone Number
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# YelpCancelFor BusinessesWrite a ReviewLog InSign UpRestaurantsHome ServicesAuto ServicesMorePai Northern Thai Kitchen2934 reviewsUnclaimed $$ ThaiEditClosed2:30 PM - 9:30 PMSee 4025 photosLoading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Loading interface...Write a ReviewAdd PhotoShareSaveMenuMost mentioned dishesPad Thai339 Photos 948 ReviewsKhao Soi288 Photos 523 ReviewsGreen Curry168 Photos 447 ReviewsPad Gra's Crispy Pork106 Photos 278 ReviewsPad Gra Prow107 Photos 281 ReviewsSpring Rolls50 Photos 193 ReviewsSquash Fritters48 Photos 150 ReviewsChef Nuit54 Photos 142 ReviewsTom Yum Soup48 Photos 132 ReviewsMango Sticky Rice44 Photos 84 ReviewsLocation & Hours18 Duncan StreetToronto, ON M5H 3G8Entertainment District, Downtown CoreGet directionsMonClosedTueClosedWed2:30 PM - 9:30 PMThu2:30 PM - 9:30 PMFri2:30 PM - 9:30 PMSat2:30 PM - 9:30 PMSun2:30 PM - 9:30 PMClosed nowEdit business infoAmenities and MoreTakes ReservationsOffers DeliveryOffers TakeoutMasks required21 More AttributesAbout the BusinessBusiness owner informationJeff and Nuit R.Business OwnerPai will be serving authentic northern Thai cuisine. And we are proud to boast that we do things the way they are meant to be, with no quality cutting short cuts.
#
# We will be serving dishes that are inspired by Chef Nuit's life in northern Thailand and also current northern Thai trends. Many dishes may be uncommonly presented in North America. Fortunately, with the reputation Chef Nuit has earned, we are confident the general public will be ready and willing to be amazed by whatever chef Nuit creates.…Read moreRecommended ReviewsYour trust is our top concern, so businesses can't pay to alter or remove their reviews. Learn more.Search within reviewsSearch within reviews  UsernameLocation001 star ratingNot good2 star ratingCould’ve been better3 star ratingOK4 star ratingGood5 star ratingGreatStart your review of Pai Northern Thai Kitchen.Clire C.Elite 2021Markham,